# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
from matplotlib import pyplot as plt

filename = 'Sample2.xlsx'
df = pd.read_excel(filename, 0)
print(df.shape[1])
gnums = int( (df.shape[1] - 2) / 7 )  # group nums
gnums
# Out:
# 16
# 2

# %%
df_new = df.iloc[:, 2:9]
Z = df.iloc[:, 1].transpose() 
Z
XY_Transpose = df_new.transpose() 
XY_Transpose
# Out:
#                0             1             2             3             4   \
# C.1  1.093680e-10  1.093740e-10  1.093850e-10  1.094140e-10  1.094160e-10
# C.2  1.093910e-10  1.094040e-10  1.094110e-10  1.094360e-10  1.094380e-10
# C.3  1.093700e-10  1.093880e-10  1.094050e-10  1.094150e-10  1.094310e-10
# C.4  1.093850e-10  1.094020e-10  1.094090e-10  1.094270e-10  1.094390e-10
# C.5  1.093840e-10  1.094030e-10  1.094130e-10  1.094280e-10  1.094380e-10
# C.6  1.093890e-10  1.094060e-10  1.094140e-10  1.094350e-10  1.094450e-10
# C.7  1.093910e-10  1.094030e-10  1.094180e-10  1.094330e-10  1.094390e-10
#
#                5             6             7             8             9   \
# C.1  1.094210e-10  1.094360e-10  1.094530e-10  1.094690e-10  1.094870e-10
# C.2  1.094500e-10  1.094650e-10  1.094820e-10  1.094930e-10  1.095040e-10
# C.3  1.094430e-10  1.094460e-10  1.094680e-10  1.094740e-10  1.094950e-10
# C.4  1.094560e-10  1.094640e-10  1.094780e-10  1.094910e-10  1.095010e-10
# C.5  1.094540e-10  1.094670e-10  1.094760e-10  1.094910e-10  1.095050e-10
# C.6  1.094530e-10  1.094670e-10  1.094760e-10  1.094910e-10  1.095030e-10
# C.7  1.094580e-10  1.094680e-10  1.094820e-10  1.094980e-10  1.095060e-10
#
#      ...            61            62            63            64  \
# C.1  ...  1.234780e-10  1.206140e-10  1.075190e-10  8.264300e-11
# C.2  ...  1.226870e-10  1.190860e-10  1.065890e-10  8.172540e-11
# C.3  ...  1.221470e-10  1.186930e-10  1.057330e-10  8.033370e-11
# C.4  ...  1.217400e-10  1.180110e-10  1.050980e-10  7.984930e-11
# C.5  ...  1.210400e-10  1.165420e-10  1.033120e-10  7.805380e-11
# C.6  ...  1.202600e-10  1.146220e-10  1.010420e-10  7.580270e-11
# C.7  ...  1.199850e-10  1.125240e-10  9.800430e-11  7.287740e-11
#
#                65            66            67            68            69  \
# C.1  4.441670e-11 -7.993590e-12 -7.389130e-11 -1.453970e-10 -2.272310e-10
# C.2  4.211120e-11 -9.455120e-12 -7.437510e-11 -1.472300e-10 -2.281610e-10
# C.3  4.160050e-11 -1.021660e-11 -7.514730e-11 -1.476740e-10 -2.282070e-10
# C.4  4.079700e-11 -1.149660e-11 -7.565290e-11 -1.483920e-10 -2.282550e-10
# C.5  3.925270e-11 -1.244900e-11 -7.622880e-11 -1.489020e-10 -2.287700e-10
# C.6  3.717290e-11 -1.385270e-11 -7.728650e-11 -1.494000e-10 -2.285830e-10
# C.7  3.477230e-11 -1.567630e-11 -7.848180e-11 -1.496620e-10 -2.284770e-10
#
#                70
# C.1 -3.137500e-10
# C.2 -3.139300e-10
# C.3 -3.145080e-10
# C.4 -3.143830e-10
# C.5 -3.148370e-10
# C.6 -3.142830e-10
# C.7 -3.135210e-10
#
# [7 rows x 71 columns]

# %%
#Z.tolist().index(-5)
Z.size
Z[0]
Z[Z.size - 1]
# Out:
# 2.0

# %%
def linear_regression(x, y):     
    N = len(x)
    x_mean = x.mean()
    y_mean = y.mean()
    
    B1_num = ((x - x_mean) * (y - y_mean)).sum()
    B1_den = ((x - x_mean)**2).sum()
    B1 = B1_num / B1_den
    
    B0 = y_mean - (B1*x_mean)
    
    reg_line = 'y = {} + {}β'.format(B0, B1)
    return (B0, B1, reg_line)

x = np.array([25, 50, 75, 100, 150, 200, 250]).transpose() * np.expm1(1e-6)
x = x.reshape((-1, 1))
for n in range(6):
    y = XY_Transpose.iloc[:, [n]].to_numpy() # 0 = Y1   
    C0, C1, reg_line =linear_regression(x, y)
    #print('Regression Line: ', reg_line)
    print('Z = ', Z_Group[n] )            
    print('C1 = ', C1)
    print('C0 = ' , C0)
    print('NDL = ', NDL)
    print('d = ', d)
# Out:
# Regression Line:  y = 1.0937369162995594e-10 + 7.312771674008725e-11β
# C0 =  1.0937369162995594e-10
# C1 =  7.312771674008725e-11
# Z =  -5.0
# Regression Line:  y = 1.093861233480176e-10 + 9.074885330399128e-11β
# C0 =  1.093861233480176e-10
# C1 =  9.074885330399128e-11
# Z =  -4.9
# Regression Line:  y = 1.0939581057268722e-10 + 9.920699885463538e-11β
# C0 =  1.0939581057268722e-10
# C1 =  9.920699885463538e-11
# Z =  -4.8
# Regression Line:  y = 1.0941907929515417e-10 + 6.40528314096953e-11β
# C0 =  1.0941907929515417e-10
# C1 =  6.40528314096953e-11
# Z =  -4.7
# Regression Line:  y = 1.0942584581497798e-10 + 7.656383837007184e-11β
# C0 =  1.0942584581497798e-10
# C1 =  7.656383837007184e-11
# Z =  -4.6
# Regression Line:  y = 1.0943476211453745e-10 + 1.0784135577092432e-10β
# C0 =  1.0943476211453745e-10
# C1 =  1.0784135577092432e-10
# Z =  -4.5

# %%
Z.tolist().index(-5)
#print (Z.index[df['B'] == 19].tolist())
# Out:
# Regression Line:  y = 1.0937369162995594e-10 + 7.312771674008725e-11β
# C0 =  1.0937369162995594e-10
# C1 =  7.312771674008725e-11
# Z =  -5.0
# 0

# %%
# Step2 -> Regression Line:  y = 1.0937369162995594e-10 + 7.312771674008725e-11β
# C0 =  1.0937369162995594e-10
# C1 =  7.312771674008725e-11
# Z =  -5.0


# Step3 Parameter cal.
q = 1.60217663 * 1e-19     # q = 1.60217663e-19
E0 = 8.854187817 * 1e-12   # E0 = 8.854187816999999e-12
Es = 11.9
A = 1 * 1e-3 


NDL = - (C0 ** 3) / (2 * q * E0 * Es * (A ** 2) * C1) # NDL = -529932456201327.06
d = (E0 * Es * A) / C0 # d = 0.0009633471582798988
